# %% [markdown]
# # Train Model

# %% [markdown]
# This code will be usede to train the a YOLO8 model on a custom data set.
# The anotated data was previusly importet in the python file 'Data_import_VT2_mini.ipynb'

# %%
# Importing the required libraries
import os
from ultralytics import YOLO

# %%
# Get the current working directory
HOME = os.getcwd()
print(f"Current working directory: {HOME}")
# Out:
# Current working directory: c:\Users\lau21\Desktop\8. semester\MINI_Project_VT2_FINAL

# %%
# Load the YOLOv8 model
model = YOLO("yolov8s.pt")

# %%
# Define the path to your dataset
dataset_path = f"{HOME}/VT2_mini_project-2"  #change path as needed

# %%
# Train the model
model.train(data=f"{dataset_path}/data.yaml", epochs=3, imgsz=640, patience=5, plots=True)
# epochs: number of epochs to train the model
# imgsz: image size for training
# Larger image sizes can improve model accuracy by providing more detail, but they also increase memory usage and training time.
# Smaller image sizes reduce memory usage and training time but may result in lower accuracy.
# patience: number of epochs with no improvement after which training will be stopped
# plots: whether to plot training results
# Out:
# New https://pypi.org/project/ultralytics/8.3.116 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103  Python-3.11.0 torch-2.6.0+cpu CPU (11th Gen Intel Core(TM) i7-1165G7 2.80GHz)
# ...

# %% [markdown]
# # Evaluate the custom trained model

# %% [markdown]
# bla bla bla

# %%
# Evaluate the model
from IPython.display import Image, display

os.chdir(HOME)
display(Image(filename=f'{HOME}/runs/detect/train4/confusion_matrix.png', width=600)) # update path

# %%
# Evaluate the model on the validation set
display(Image(filename=f'{HOME}/runs/detect/train4/results.png', width=600))

# %%
# Evaluate the model on the test set
display(Image(filename=f'{HOME}/runs/detect/train4/val_batch0_pred.jpg', width=600))
